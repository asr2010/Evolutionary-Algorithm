# %%
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt
import time

# Load and preprocess the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
y_train, y_test = tf.keras.utils.to_categorical(y_train), tf.keras.utils.to_categorical(y_test)

validation_split = 0.1
split_index = int(len(x_train) * validation_split)
x_val, y_val = x_train[:split_index], y_train[:split_index]
x_train, y_train = x_train[split_index:], y_train[split_index:]

sample_size = 5000  # Adjust this value as needed
sample_indices = np.random.choice(np.arange(x_train.shape[0]), sample_size, replace=False)

x_train_small = x_train[sample_indices]
y_train_small = y_train[sample_indices]

# Define the fitness function
def fitness_function(num_filters1, num_filters2, dense_units, learning_rate):
    num_filters1 = max(1, round(num_filters1))
    num_filters2 = max(1, round(num_filters2))
    dense_units = max(1, round(dense_units))
    print(f"num_filters1: {num_filters1}, num_filters2: {num_filters2}")
    model = Sequential([
        Conv2D(num_filters1, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
        BatchNormalization(),
        Conv2D(num_filters1, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.25),

        Conv2D(num_filters2, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(num_filters2, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.25),

        Flatten(),
        Dense(dense_units, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(10, activation='softmax')
    ])

    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    history = model.fit(x_train_small, y_train_small, epochs=10, batch_size=256,
                        validation_data=(x_val, y_val),
                        callbacks=[early_stopping],
                        verbose=0)

    return history.history['val_loss'][-1]

# Define the ACO class
class ACO:
    def __init__(self, fitness_function, colony_size, n_iterations, num_params, lower_bounds, upper_bounds, alpha, beta, rho, q, seed=None, num_discrete_values=10, randomness_factor=0.1):
        self.fitness_function = fitness_function
        self.colony_size = colony_size
        self.n_iterations = n_iterations
        self.num_params = num_params
        self.lower_bounds = lower_bounds
        self.upper_bounds = upper_bounds
        self.alpha = alpha
        self.beta = beta
        self.rho = rho
        self.q = q
        self.seed = seed
        self.num_discrete_values = num_discrete_values
        self.randomness_factor = randomness_factor
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)

        # Create the discretized search space for each parameter
        self.discrete_values = [np.linspace(lower_bounds[i], upper_bounds[i], num=self.num_discrete_values) for i in range(self.num_params)]

        # Initialize the pheromone matrix
        self.pheromone_matrix = np.ones((self.num_params, self.num_discrete_values))

    def run(self):
        best_solution = None
        best_fitness = float('inf')

        for iteration in range(self.n_iterations):
            solutions = []
            fitnesses = []
            discrete_solution_indices_list = []

            for ant_index in range(self.colony_size):
                solution = []
                discrete_solution_indices = []

                for i in range(self.num_params):
                    probabilities = self.pheromone_matrix[i] ** self.alpha * (1 / self.discrete_values[i]) ** self.beta
                    probabilities /= np.sum(probabilities)
                    
                    # Add randomness
                    if random.random() < self.randomness_factor:
                        discrete_index = random.randint(0, self.num_discrete_values - 1)
                    else:
                        discrete_index = np.random.choice(np.arange(self.num_discrete_values), p=probabilities)

                    solution.append(self.discrete_values[i][discrete_index])
                    discrete_solution_indices.append(discrete_index)

                # Print progress before evaluating the fitness
                print(f'Iteration {iteration + 1}, Ant {ant_index + 1}: Evaluating...')
                fitness = self.fitness_function(*solution)

                solutions.append(solution)
                fitnesses.append(fitness)
                discrete_solution_indices_list.append(discrete_solution_indices)

                if fitness < best_fitness:
                    best_fitness = fitness
                    best_solution = solution

                # Print progress of each ant
                print(f'Iteration {iteration + 1}, Ant {ant_index + 1}: Current solution: {solution}, Current validation loss: {fitness}')

            # Update pheromone levels after all ants have completed their search in the current iteration
            for ant_index in range(self.colony_size):
                fitness = fitnesses[ant_index]
                discrete_solution_indices = discrete_solution_indices_list[ant_index]
                for i in range(self.num_params):
                    self.pheromone_matrix[i] *= (1 - self.rho)
                    self.pheromone_matrix[i, discrete_solution_indices[i]] += self.q / fitness

            print(f'Iteration {iteration + 1}: Best solution: {best_solution}, Best validation loss: {best_fitness}')

        return best_solution, best_fitness



# Set the ACO hyperparameters and bounds for the CNN hyperparameters
colony_size = 20
n_iterations = 20
num_params = 4
lower_bounds = [16, 16, 256, 0.0001]
upper_bounds = [128, 128, 1024, 0.01]
alpha = 1
beta = 4.5
rho = 0.8
q = 0.5
randomness_factor = 0.5

# Create and run the ACO optimizer
print("Starting the ACO optimizer...")
aco = ACO(fitness_function, colony_size, n_iterations, num_params, lower_bounds, upper_bounds, alpha, beta, rho, q, seed=42,randomness_factor=randomness_factor)
best_hyperparameters, best_val_loss = aco.run()

best_num_filters1, best_num_filters2, best_dense_units, best_learning_rate = best_hyperparameters
best_num_filters1, best_num_filters2, best_dense_units = int(best_num_filters1), int(best_num_filters2), int(best_dense_units)

print(f"Best hyperparameters found by ACO: num_filters1={best_num_filters1}, "
      f"num_filters2={best_num_filters2}, dense_units={best_dense_units}, "
      f"learning_rate={best_learning_rate}")

# Train the model with the best hyperparameters found by ACO
print("Training the model with the best hyperparameters...")

# Train the model with the best hyperparameters found by ACO
best_model = Sequential([
    Conv2D(best_num_filters1, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    BatchNormalization(),
    Conv2D(best_num_filters1, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Conv2D(best_num_filters2, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(best_num_filters2, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Flatten(),
    Dense(best_dense_units, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

best_model.compile(optimizer=Adam(learning_rate=best_learning_rate),
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

start_time = time.time()
history = best_model.fit(x_train, y_train, epochs=50, batch_size=64,
                         validation_data=(x_val, y_val),
                         callbacks=[early_stopping],
                         verbose=1)
end_time = time.time()

training_time = end_time - start_time
print(f'Total training time: {training_time:.2f} seconds')

# Evaluate the best model on the test dataset
print("Evaluating the model on the test dataset...")
test_loss, test_acc = best_model.evaluate(x_test, y_test, verbose=0)
y_pred = best_model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

print(f'Test accuracy: {test_acc}')

print("Classification Report:")
print(classification_report(y_test_classes, y_pred_classes))

print("Confusion Matrix:")
print(confusion_matrix(y_test_classes, y_pred_classes))

# Calculate ROC-AUC for multi-class classification
roc_auc = roc_auc_score(y_test, y_pred, multi_class='ovr')
print(f'ROC-AUC Score: {roc_auc}')

# Plot the training and validation accuracies
print("Plotting the training and validation accuracies...")
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Starting the ACO optimizer...
# Iteration 1, Ant 1: Evaluating...
# num_filters1: 16, num_filters2: 66
# Iteration 1, Ant 1: Current solution: [16.0, 65.77777777777777, 426.66666666666663, 0.0001], Current validation loss: 3.565580129623413
# Iteration 1, Ant 2: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 1, Ant 2: Current solution: [16.0, 53.333333333333336, 341.3333333333333, 0.0034], Current validation loss: 3.2784926891326904
# Iteration 1, Ant 3: Evaluating...
# num_filters1: 66, num_filters2: 16
# Iteration 1, Ant 3: Current solution: [65.77777777777777, 16.0, 426.66666666666663, 0.0001], Current validation loss: 2.97951340675354
# Iteration 1, Ant 4: Evaluating...
# num_filters1: 91, num_filters2: 78
# Iteration 1, Ant 4: Current solution: [90.66666666666667, 78.22222222222223, 256.0, 0.0001], Current validation loss: 3.008910655975342
# Iteration 1, Ant 5: Evaluating...
# num_filters1: 66, num_filters2: 16
# Iteration 1, Ant 5: Current solution: [65.77777777777777, 16.0, 256.0, 0.0001], Current validation loss: 2.5494062900543213
# Iteration 1, Ant 6: Evaluating...
# num_filters1: 66, num_filters2: 16
# Iteration 1, Ant 6: Current solution: [65.77777777777777, 16.0, 597.3333333333333, 0.0001], Current validation loss: 2.7041220664978027
# Iteration 1, Ant 7: Evaluating...
# num_filters1: 78, num_filters2: 66
# Iteration 1, Ant 7: Current solution: [78.22222222222223, 65.77777777777777, 256.0, 0.0001], Current validation loss: 3.470139741897583
# Iteration 1, Ant 8: Evaluating...
# num_filters1: 103, num_filters2: 116
# Iteration 1, Ant 8: Current solution: [103.11111111111111, 115.55555555555556, 682.6666666666666, 0.0001], Current validation loss: 3.4484715461730957
# Iteration 1, Ant 9: Evaluating...
# num_filters1: 66, num_filters2: 128
# Iteration 1, Ant 9: Current solution: [65.77777777777777, 128.0, 256.0, 0.0078000000000000005], Current validation loss: 3.8389968872070312
# Iteration 1, Ant 10: Evaluating...
# num_filters1: 53, num_filters2: 16
# Iteration 1, Ant 10: Current solution: [53.333333333333336, 16.0, 256.0, 0.0001], Current validation loss: 2.8438267707824707
# Iteration 1, Ant 11: Evaluating...
# num_filters1: 16, num_filters2: 103
# Iteration 1, Ant 11: Current solution: [16.0, 103.11111111111111, 256.0, 0.0001], Current validation loss: 2.7282750606536865
# Iteration 1, Ant 12: Evaluating...
# num_filters1: 16, num_filters2: 128
# Iteration 1, Ant 12: Current solution: [16.0, 128.0, 256.0, 0.0001], Current validation loss: 3.2887656688690186
# Iteration 1, Ant 13: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 1, Ant 13: Current solution: [16.0, 16.0, 682.6666666666666, 0.0067], Current validation loss: 3.245650291442871
# Iteration 1, Ant 14: Evaluating...
# num_filters1: 116, num_filters2: 16
# Iteration 1, Ant 14: Current solution: [115.55555555555556, 16.0, 256.0, 0.0045000000000000005], Current validation loss: 3.8568944931030273
# Iteration 1, Ant 15: Evaluating...
# num_filters1: 41, num_filters2: 16
# Iteration 1, Ant 15: Current solution: [40.888888888888886, 16.0, 256.0, 0.0001], Current validation loss: 2.6943445205688477
# Iteration 1, Ant 16: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 1, Ant 16: Current solution: [16.0, 28.444444444444443, 597.3333333333333, 0.0001], Current validation loss: 3.058955192565918
# Iteration 1, Ant 17: Evaluating...
# num_filters1: 28, num_filters2: 16
# Iteration 1, Ant 17: Current solution: [28.444444444444443, 16.0, 256.0, 0.0078000000000000005], Current validation loss: 3.689319610595703
# Iteration 1, Ant 18: Evaluating...
# num_filters1: 53, num_filters2: 16
# Iteration 1, Ant 18: Current solution: [53.333333333333336, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.8343100547790527
# Iteration 1, Ant 19: Evaluating...
# num_filters1: 116, num_filters2: 53
# Iteration 1, Ant 19: Current solution: [115.55555555555556, 53.333333333333336, 682.6666666666666, 0.0089], Current validation loss: 4.112302780151367
# Iteration 1, Ant 20: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 1, Ant 20: Current solution: [16.0, 16.0, 256.0, 0.0034], Current validation loss: 3.4970004558563232
# Iteration 1: Best solution: [65.77777777777777, 16.0, 256.0, 0.0001], Best validation loss: 2.5494062900543213
# Iteration 2, Ant 1: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 2, Ant 1: Current solution: [16.0, 16.0, 256.0, 0.0078000000000000005], Current validation loss: 2.7171053886413574
# Iteration 2, Ant 2: Evaluating...
# num_filters1: 91, num_filters2: 16
# Iteration 2, Ant 2: Current solution: [90.66666666666667, 16.0, 256.0, 0.0001], Current validation loss: 3.3809316158294678
# Iteration 2, Ant 3: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 2, Ant 3: Current solution: [16.0, 53.333333333333336, 256.0, 0.0023], Current validation loss: 3.10170578956604
# Iteration 2, Ant 4: Evaluating...
# num_filters1: 116, num_filters2: 116
# Iteration 2, Ant 4: Current solution: [115.55555555555556, 115.55555555555556, 256.0, 0.0001], Current validation loss: 2.81252384185791
# Iteration 2, Ant 5: Evaluating...
# num_filters1: 53, num_filters2: 16
# Iteration 2, Ant 5: Current solution: [53.333333333333336, 16.0, 256.0, 0.0001], Current validation loss: 2.8874504566192627
# Iteration 2, Ant 6: Evaluating...
# num_filters1: 116, num_filters2: 16
# Iteration 2, Ant 6: Current solution: [115.55555555555556, 16.0, 512.0, 0.0001], Current validation loss: 3.2826602458953857
# Iteration 2, Ant 7: Evaluating...
# num_filters1: 128, num_filters2: 116
# Iteration 2, Ant 7: Current solution: [128.0, 115.55555555555556, 938.6666666666666, 0.0023], Current validation loss: 5.313266754150391
# Iteration 2, Ant 8: Evaluating...
# num_filters1: 128, num_filters2: 128
# Iteration 2, Ant 8: Current solution: [128.0, 128.0, 341.3333333333333, 0.01], Current validation loss: 2.7593088150024414
# Iteration 2, Ant 9: Evaluating...
# num_filters1: 16, num_filters2: 91
# Iteration 2, Ant 9: Current solution: [16.0, 90.66666666666667, 597.3333333333333, 0.0012000000000000001], Current validation loss: 5.104121685028076
# Iteration 2, Ant 10: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 2, Ant 10: Current solution: [16.0, 16.0, 682.6666666666666, 0.0001], Current validation loss: 2.597768545150757
# Iteration 2, Ant 11: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 2, Ant 11: Current solution: [16.0, 16.0, 256.0, 0.0001], Current validation loss: 2.5417563915252686
# Iteration 2, Ant 12: Evaluating...
# num_filters1: 28, num_filters2: 16
# Iteration 2, Ant 12: Current solution: [28.444444444444443, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.445847272872925
# Iteration 2, Ant 13: Evaluating...
# num_filters1: 78, num_filters2: 66
# Iteration 2, Ant 13: Current solution: [78.22222222222223, 65.77777777777777, 256.0, 0.0001], Current validation loss: 2.9583582878112793
# Iteration 2, Ant 14: Evaluating...
# num_filters1: 41, num_filters2: 16
# Iteration 2, Ant 14: Current solution: [40.888888888888886, 16.0, 853.3333333333333, 0.0001], Current validation loss: 3.23555850982666
# Iteration 2, Ant 15: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 2, Ant 15: Current solution: [16.0, 16.0, 256.0, 0.0001], Current validation loss: 2.6550047397613525
# Iteration 2, Ant 16: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 2, Ant 16: Current solution: [16.0, 16.0, 256.0, 0.0001], Current validation loss: 2.6374003887176514
# Iteration 2, Ant 17: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 2, Ant 17: Current solution: [16.0, 16.0, 1024.0, 0.0001], Current validation loss: 3.1319117546081543
# Iteration 2, Ant 18: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 2, Ant 18: Current solution: [16.0, 16.0, 682.6666666666666, 0.0001], Current validation loss: 2.833996057510376
# Iteration 2, Ant 19: Evaluating...
# num_filters1: 41, num_filters2: 16
# Iteration 2, Ant 19: Current solution: [40.888888888888886, 16.0, 256.0, 0.0001], Current validation loss: 2.8741629123687744
# Iteration 2, Ant 20: Evaluating...
# num_filters1: 53, num_filters2: 53
# Iteration 2, Ant 20: Current solution: [53.333333333333336, 53.333333333333336, 597.3333333333333, 0.0001], Current validation loss: 3.523400068283081
# Iteration 2: Best solution: [28.444444444444443, 16.0, 341.3333333333333, 0.0001], Best validation loss: 2.445847272872925
# Iteration 3, Ant 1: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 3, Ant 1: Current solution: [16.0, 16.0, 256.0, 0.0045000000000000005], Current validation loss: 2.9264039993286133
# Iteration 3, Ant 2: Evaluating...
# num_filters1: 78, num_filters2: 116
# Iteration 3, Ant 2: Current solution: [78.22222222222223, 115.55555555555556, 1024.0, 0.0001], Current validation loss: 4.181761264801025
# Iteration 3, Ant 3: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 3, Ant 3: Current solution: [16.0, 16.0, 256.0, 0.0001], Current validation loss: 2.9337828159332275
# Iteration 3, Ant 4: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 3, Ant 4: Current solution: [16.0, 16.0, 597.3333333333333, 0.0001], Current validation loss: 3.023979425430298
# Iteration 3, Ant 5: Evaluating...
# num_filters1: 16, num_filters2: 91
# Iteration 3, Ant 5: Current solution: [16.0, 90.66666666666667, 256.0, 0.0001], Current validation loss: 3.214747190475464
# Iteration 3, Ant 6: Evaluating...
# num_filters1: 66, num_filters2: 128
# Iteration 3, Ant 6: Current solution: [65.77777777777777, 128.0, 256.0, 0.0078000000000000005], Current validation loss: 4.384378910064697
# Iteration 3, Ant 7: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 3, Ant 7: Current solution: [16.0, 16.0, 341.3333333333333, 0.01], Current validation loss: 2.721284866333008
# Iteration 3, Ant 8: Evaluating...
# num_filters1: 53, num_filters2: 16
# Iteration 3, Ant 8: Current solution: [53.333333333333336, 16.0, 853.3333333333333, 0.0001], Current validation loss: 3.0022549629211426
# Iteration 3, Ant 9: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 3, Ant 9: Current solution: [16.0, 16.0, 768.0, 0.0001], Current validation loss: 2.7631592750549316
# Iteration 3, Ant 10: Evaluating...
# num_filters1: 16, num_filters2: 116
# Iteration 3, Ant 10: Current solution: [16.0, 115.55555555555556, 938.6666666666666, 0.0012000000000000001], Current validation loss: 4.186344146728516
# Iteration 3, Ant 11: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 3, Ant 11: Current solution: [16.0, 16.0, 256.0, 0.0001], Current validation loss: 2.9034440517425537
# Iteration 3, Ant 12: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 3, Ant 12: Current solution: [16.0, 16.0, 256.0, 0.0001], Current validation loss: 3.176417112350464
# Iteration 3, Ant 13: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 3, Ant 13: Current solution: [16.0, 16.0, 597.3333333333333, 0.0001], Current validation loss: 2.9739246368408203
# Iteration 3, Ant 14: Evaluating...
# num_filters1: 78, num_filters2: 16
# Iteration 3, Ant 14: Current solution: [78.22222222222223, 16.0, 426.66666666666663, 0.0023], Current validation loss: 3.1588971614837646
# Iteration 3, Ant 15: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 3, Ant 15: Current solution: [16.0, 53.333333333333336, 256.0, 0.01], Current validation loss: 2.8765106201171875
# Iteration 3, Ant 16: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 3, Ant 16: Current solution: [16.0, 16.0, 768.0, 0.0001], Current validation loss: 3.1997897624969482
# Iteration 3, Ant 17: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 3, Ant 17: Current solution: [16.0, 16.0, 597.3333333333333, 0.0001], Current validation loss: 2.966632127761841
# Iteration 3, Ant 18: Evaluating...
# num_filters1: 41, num_filters2: 16
# Iteration 3, Ant 18: Current solution: [40.888888888888886, 16.0, 256.0, 0.0001], Current validation loss: 2.850454330444336
# Iteration 3, Ant 19: Evaluating...
# num_filters1: 16, num_filters2: 91
# Iteration 3, Ant 19: Current solution: [16.0, 90.66666666666667, 853.3333333333333, 0.0045000000000000005], Current validation loss: 5.466010093688965
# Iteration 3, Ant 20: Evaluating...
# num_filters1: 16, num_filters2: 91
# Iteration 3, Ant 20: Current solution: [16.0, 90.66666666666667, 341.3333333333333, 0.0089], Current validation loss: 2.5902698040008545
# Iteration 3: Best solution: [28.444444444444443, 16.0, 341.3333333333333, 0.0001], Best validation loss: 2.445847272872925
# Iteration 4, Ant 1: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 4, Ant 1: Current solution: [16.0, 16.0, 256.0, 0.0001], Current validation loss: 2.6647067070007324
# Iteration 4, Ant 2: Evaluating...
# num_filters1: 53, num_filters2: 66
# Iteration 4, Ant 2: Current solution: [53.333333333333336, 65.77777777777777, 341.3333333333333, 0.01], Current validation loss: 2.321383476257324
# Iteration 4, Ant 3: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 4, Ant 3: Current solution: [16.0, 16.0, 341.3333333333333, 0.0001], Current validation loss: 3.1838250160217285
# Iteration 4, Ant 4: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 4, Ant 4: Current solution: [16.0, 16.0, 597.3333333333333, 0.0001], Current validation loss: 3.4439918994903564
# Iteration 4, Ant 5: Evaluating...
# num_filters1: 116, num_filters2: 78
# Iteration 4, Ant 5: Current solution: [115.55555555555556, 78.22222222222223, 682.6666666666666, 0.0067], Current validation loss: 4.522472858428955
# Iteration 4, Ant 6: Evaluating...
# num_filters1: 16, num_filters2: 41
# Iteration 4, Ant 6: Current solution: [16.0, 40.888888888888886, 938.6666666666666, 0.0001], Current validation loss: 3.849083662033081
# Iteration 4, Ant 7: Evaluating...
# num_filters1: 91, num_filters2: 16
# Iteration 4, Ant 7: Current solution: [90.66666666666667, 16.0, 341.3333333333333, 0.0034], Current validation loss: 3.2164528369903564
# Iteration 4, Ant 8: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 4, Ant 8: Current solution: [16.0, 16.0, 341.3333333333333, 0.0078000000000000005], Current validation loss: 6.559765815734863
# Iteration 4, Ant 9: Evaluating...
# num_filters1: 16, num_filters2: 128
# Iteration 4, Ant 9: Current solution: [16.0, 128.0, 341.3333333333333, 0.0001], Current validation loss: 3.636319875717163
# Iteration 4, Ant 10: Evaluating...
# num_filters1: 53, num_filters2: 16
# Iteration 4, Ant 10: Current solution: [53.333333333333336, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.7505836486816406
# Iteration 4, Ant 11: Evaluating...
# num_filters1: 128, num_filters2: 116
# Iteration 4, Ant 11: Current solution: [128.0, 115.55555555555556, 341.3333333333333, 0.0089], Current validation loss: 2.854750633239746
# Iteration 4, Ant 12: Evaluating...
# num_filters1: 28, num_filters2: 16
# Iteration 4, Ant 12: Current solution: [28.444444444444443, 16.0, 938.6666666666666, 0.0001], Current validation loss: 2.90185809135437
# Iteration 4, Ant 13: Evaluating...
# num_filters1: 128, num_filters2: 16
# Iteration 4, Ant 13: Current solution: [128.0, 16.0, 341.3333333333333, 0.0012000000000000001], Current validation loss: 3.5367534160614014
# Iteration 4, Ant 14: Evaluating...
# num_filters1: 116, num_filters2: 16
# Iteration 4, Ant 14: Current solution: [115.55555555555556, 16.0, 341.3333333333333, 0.0001], Current validation loss: 3.2813663482666016
# Iteration 4, Ant 15: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 4, Ant 15: Current solution: [16.0, 16.0, 853.3333333333333, 0.0001], Current validation loss: 2.879016637802124
# Iteration 4, Ant 16: Evaluating...
# num_filters1: 28, num_filters2: 16
# Iteration 4, Ant 16: Current solution: [28.444444444444443, 16.0, 341.3333333333333, 0.01], Current validation loss: 2.598053216934204
# Iteration 4, Ant 17: Evaluating...
# num_filters1: 128, num_filters2: 16
# Iteration 4, Ant 17: Current solution: [128.0, 16.0, 938.6666666666666, 0.0078000000000000005], Current validation loss: 3.130476236343384
# Iteration 4, Ant 18: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 4, Ant 18: Current solution: [16.0, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.641080141067505
# Iteration 4, Ant 19: Evaluating...
# num_filters1: 41, num_filters2: 16
# Iteration 4, Ant 19: Current solution: [40.888888888888886, 16.0, 768.0, 0.01], Current validation loss: 3.2271857261657715
# Iteration 4, Ant 20: Evaluating...
# num_filters1: 103, num_filters2: 53
# Iteration 4, Ant 20: Current solution: [103.11111111111111, 53.333333333333336, 341.3333333333333, 0.0001], Current validation loss: 2.9011926651000977
# Iteration 4: Best solution: [53.333333333333336, 65.77777777777777, 341.3333333333333, 0.01], Best validation loss: 2.321383476257324
# Iteration 5, Ant 1: Evaluating...
# num_filters1: 53, num_filters2: 16
# Iteration 5, Ant 1: Current solution: [53.333333333333336, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.9792308807373047
# Iteration 5, Ant 2: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 5, Ant 2: Current solution: [16.0, 16.0, 341.3333333333333, 0.0045000000000000005], Current validation loss: 3.561269998550415
# Iteration 5, Ant 3: Evaluating...
# num_filters1: 128, num_filters2: 91
# Iteration 5, Ant 3: Current solution: [128.0, 90.66666666666667, 341.3333333333333, 0.0001], Current validation loss: 3.537630558013916
# Iteration 5, Ant 4: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 5, Ant 4: Current solution: [16.0, 16.0, 341.3333333333333, 0.0001], Current validation loss: 3.1015636920928955
# Iteration 5, Ant 5: Evaluating...
# num_filters1: 103, num_filters2: 16
# Iteration 5, Ant 5: Current solution: [103.11111111111111, 16.0, 1024.0, 0.0078000000000000005], Current validation loss: 2.68772554397583
# Iteration 5, Ant 6: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 5, Ant 6: Current solution: [16.0, 16.0, 853.3333333333333, 0.0067], Current validation loss: 2.7823121547698975
# Iteration 5, Ant 7: Evaluating...
# num_filters1: 78, num_filters2: 91
# Iteration 5, Ant 7: Current solution: [78.22222222222223, 90.66666666666667, 341.3333333333333, 0.0001], Current validation loss: 2.8337278366088867
# Iteration 5, Ant 8: Evaluating...
# num_filters1: 116, num_filters2: 103
# Iteration 5, Ant 8: Current solution: [115.55555555555556, 103.11111111111111, 341.3333333333333, 0.0001], Current validation loss: 3.4478180408477783
# Iteration 5, Ant 9: Evaluating...
# num_filters1: 103, num_filters2: 128
# Iteration 5, Ant 9: Current solution: [103.11111111111111, 128.0, 341.3333333333333, 0.0001], Current validation loss: 3.7154102325439453
# Iteration 5, Ant 10: Evaluating...
# num_filters1: 28, num_filters2: 28
# Iteration 5, Ant 10: Current solution: [28.444444444444443, 28.444444444444443, 341.3333333333333, 0.0045000000000000005], Current validation loss: 3.7537643909454346
# Iteration 5, Ant 11: Evaluating...
# num_filters1: 16, num_filters2: 116
# Iteration 5, Ant 11: Current solution: [16.0, 115.55555555555556, 512.0, 0.0001], Current validation loss: 3.0777764320373535
# Iteration 5, Ant 12: Evaluating...
# num_filters1: 91, num_filters2: 116
# Iteration 5, Ant 12: Current solution: [90.66666666666667, 115.55555555555556, 256.0, 0.0045000000000000005], Current validation loss: 4.365268230438232
# Iteration 5, Ant 13: Evaluating...
# num_filters1: 116, num_filters2: 78
# Iteration 5, Ant 13: Current solution: [115.55555555555556, 78.22222222222223, 341.3333333333333, 0.0001], Current validation loss: 2.8026087284088135
# Iteration 5, Ant 14: Evaluating...
# num_filters1: 16, num_filters2: 91
# Iteration 5, Ant 14: Current solution: [16.0, 90.66666666666667, 853.3333333333333, 0.0001], Current validation loss: 3.9416542053222656
# Iteration 5, Ant 15: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 5, Ant 15: Current solution: [16.0, 16.0, 1024.0, 0.0012000000000000001], Current validation loss: 2.951018810272217
# Iteration 5, Ant 16: Evaluating...
# num_filters1: 41, num_filters2: 41
# Iteration 5, Ant 16: Current solution: [40.888888888888886, 40.888888888888886, 597.3333333333333, 0.0067], Current validation loss: 3.0670225620269775
# Iteration 5, Ant 17: Evaluating...
# num_filters1: 16, num_filters2: 78
# Iteration 5, Ant 17: Current solution: [16.0, 78.22222222222223, 341.3333333333333, 0.0001], Current validation loss: 3.2079575061798096
# Iteration 5, Ant 18: Evaluating...
# num_filters1: 66, num_filters2: 16
# Iteration 5, Ant 18: Current solution: [65.77777777777777, 16.0, 341.3333333333333, 0.0012000000000000001], Current validation loss: 2.877154588699341
# Iteration 5, Ant 19: Evaluating...
# num_filters1: 66, num_filters2: 16
# Iteration 5, Ant 19: Current solution: [65.77777777777777, 16.0, 256.0, 0.005600000000000001], Current validation loss: 2.6911191940307617
# Iteration 5, Ant 20: Evaluating...
# num_filters1: 16, num_filters2: 41
# Iteration 5, Ant 20: Current solution: [16.0, 40.888888888888886, 768.0, 0.0001], Current validation loss: 3.034433126449585
# Iteration 5: Best solution: [53.333333333333336, 65.77777777777777, 341.3333333333333, 0.01], Best validation loss: 2.321383476257324
# Iteration 6, Ant 1: Evaluating...
# num_filters1: 66, num_filters2: 16
# Iteration 6, Ant 1: Current solution: [65.77777777777777, 16.0, 256.0, 0.0045000000000000005], Current validation loss: 3.4118988513946533
# Iteration 6, Ant 2: Evaluating...
# num_filters1: 16, num_filters2: 91
# Iteration 6, Ant 2: Current solution: [16.0, 90.66666666666667, 256.0, 0.0045000000000000005], Current validation loss: 4.187201499938965
# Iteration 6, Ant 3: Evaluating...
# num_filters1: 78, num_filters2: 16
# Iteration 6, Ant 3: Current solution: [78.22222222222223, 16.0, 256.0, 0.0067], Current validation loss: 3.156330108642578
# Iteration 6, Ant 4: Evaluating...
# num_filters1: 16, num_filters2: 128
# Iteration 6, Ant 4: Current solution: [16.0, 128.0, 256.0, 0.0001], Current validation loss: 3.693652391433716
# Iteration 6, Ant 5: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 6, Ant 5: Current solution: [16.0, 53.333333333333336, 256.0, 0.0001], Current validation loss: 3.1252057552337646
# Iteration 6, Ant 6: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 6, Ant 6: Current solution: [16.0, 16.0, 256.0, 0.0078000000000000005], Current validation loss: 2.8231594562530518
# Iteration 6, Ant 7: Evaluating...
# num_filters1: 16, num_filters2: 91
# Iteration 6, Ant 7: Current solution: [16.0, 90.66666666666667, 426.66666666666663, 0.0001], Current validation loss: 3.1697585582733154
# Iteration 6, Ant 8: Evaluating...
# num_filters1: 16, num_filters2: 103
# Iteration 6, Ant 8: Current solution: [16.0, 103.11111111111111, 256.0, 0.005600000000000001], Current validation loss: 4.1051025390625
# Iteration 6, Ant 9: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 6, Ant 9: Current solution: [16.0, 16.0, 256.0, 0.0001], Current validation loss: 2.7672901153564453
# Iteration 6, Ant 10: Evaluating...
# num_filters1: 66, num_filters2: 16
# Iteration 6, Ant 10: Current solution: [65.77777777777777, 16.0, 597.3333333333333, 0.0001], Current validation loss: 2.7297403812408447
# Iteration 6, Ant 11: Evaluating...
# num_filters1: 128, num_filters2: 16
# Iteration 6, Ant 11: Current solution: [128.0, 16.0, 768.0, 0.0001], Current validation loss: 2.90834641456604
# Iteration 6, Ant 12: Evaluating...
# num_filters1: 16, num_filters2: 91
# Iteration 6, Ant 12: Current solution: [16.0, 90.66666666666667, 256.0, 0.0001], Current validation loss: 3.2953195571899414
# Iteration 6, Ant 13: Evaluating...
# num_filters1: 16, num_filters2: 78
# Iteration 6, Ant 13: Current solution: [16.0, 78.22222222222223, 256.0, 0.0001], Current validation loss: 2.57658314704895
# Iteration 6, Ant 14: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 6, Ant 14: Current solution: [16.0, 16.0, 256.0, 0.0001], Current validation loss: 2.701281785964966
# Iteration 6, Ant 15: Evaluating...
# num_filters1: 53, num_filters2: 16
# Iteration 6, Ant 15: Current solution: [53.333333333333336, 16.0, 682.6666666666666, 0.0001], Current validation loss: 3.438467502593994
# Iteration 6, Ant 16: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 6, Ant 16: Current solution: [16.0, 16.0, 341.3333333333333, 0.0034], Current validation loss: 2.95556378364563
# Iteration 6, Ant 17: Evaluating...
# num_filters1: 41, num_filters2: 16
# Iteration 6, Ant 17: Current solution: [40.888888888888886, 16.0, 938.6666666666666, 0.0034], Current validation loss: 3.0449163913726807
# Iteration 6, Ant 18: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 6, Ant 18: Current solution: [16.0, 16.0, 426.66666666666663, 0.0001], Current validation loss: 3.101060628890991
# Iteration 6, Ant 19: Evaluating...
# num_filters1: 16, num_filters2: 78
# Iteration 6, Ant 19: Current solution: [16.0, 78.22222222222223, 341.3333333333333, 0.005600000000000001], Current validation loss: 4.9676618576049805
# Iteration 6, Ant 20: Evaluating...
# num_filters1: 28, num_filters2: 41
# Iteration 6, Ant 20: Current solution: [28.444444444444443, 40.888888888888886, 682.6666666666666, 0.0001], Current validation loss: 3.0749921798706055
# Iteration 6: Best solution: [53.333333333333336, 65.77777777777777, 341.3333333333333, 0.01], Best validation loss: 2.321383476257324
# Iteration 7, Ant 1: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 7, Ant 1: Current solution: [16.0, 16.0, 682.6666666666666, 0.0001], Current validation loss: 3.1860105991363525
# Iteration 7, Ant 2: Evaluating...
# num_filters1: 103, num_filters2: 28
# Iteration 7, Ant 2: Current solution: [103.11111111111111, 28.444444444444443, 426.66666666666663, 0.0045000000000000005], Current validation loss: 5.274359703063965
# Iteration 7, Ant 3: Evaluating...
# num_filters1: 128, num_filters2: 16
# Iteration 7, Ant 3: Current solution: [128.0, 16.0, 1024.0, 0.0012000000000000001], Current validation loss: 3.2830708026885986
# Iteration 7, Ant 4: Evaluating...
# num_filters1: 16, num_filters2: 103
# Iteration 7, Ant 4: Current solution: [16.0, 103.11111111111111, 341.3333333333333, 0.0078000000000000005], Current validation loss: 3.0876500606536865
# Iteration 7, Ant 5: Evaluating...
# num_filters1: 66, num_filters2: 41
# Iteration 7, Ant 5: Current solution: [65.77777777777777, 40.888888888888886, 682.6666666666666, 0.0012000000000000001], Current validation loss: 4.832005500793457
# Iteration 7, Ant 6: Evaluating...
# num_filters1: 28, num_filters2: 16
# Iteration 7, Ant 6: Current solution: [28.444444444444443, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.6021969318389893
# Iteration 7, Ant 7: Evaluating...
# num_filters1: 91, num_filters2: 41
# Iteration 7, Ant 7: Current solution: [90.66666666666667, 40.888888888888886, 341.3333333333333, 0.0001], Current validation loss: 3.3942558765411377
# Iteration 7, Ant 8: Evaluating...
# num_filters1: 103, num_filters2: 28
# Iteration 7, Ant 8: Current solution: [103.11111111111111, 28.444444444444443, 938.6666666666666, 0.0045000000000000005], Current validation loss: 3.1709625720977783
# Iteration 7, Ant 9: Evaluating...
# num_filters1: 28, num_filters2: 16
# Iteration 7, Ant 9: Current solution: [28.444444444444443, 16.0, 426.66666666666663, 0.0001], Current validation loss: 2.803007125854492
# Iteration 7, Ant 10: Evaluating...
# num_filters1: 41, num_filters2: 66
# Iteration 7, Ant 10: Current solution: [40.888888888888886, 65.77777777777777, 341.3333333333333, 0.0023], Current validation loss: 5.636102199554443
# Iteration 7, Ant 11: Evaluating...
# num_filters1: 16, num_filters2: 116
# Iteration 7, Ant 11: Current solution: [16.0, 115.55555555555556, 768.0, 0.0023], Current validation loss: 7.683984279632568
# Iteration 7, Ant 12: Evaluating...
# num_filters1: 16, num_filters2: 41
# Iteration 7, Ant 12: Current solution: [16.0, 40.888888888888886, 1024.0, 0.0012000000000000001], Current validation loss: 4.471484184265137
# Iteration 7, Ant 13: Evaluating...
# num_filters1: 66, num_filters2: 116
# Iteration 7, Ant 13: Current solution: [65.77777777777777, 115.55555555555556, 768.0, 0.01], Current validation loss: 4.758928298950195
# Iteration 7, Ant 14: Evaluating...
# num_filters1: 128, num_filters2: 53
# Iteration 7, Ant 14: Current solution: [128.0, 53.333333333333336, 512.0, 0.0001], Current validation loss: 3.5180327892303467
# Iteration 7, Ant 15: Evaluating...
# num_filters1: 91, num_filters2: 91
# Iteration 7, Ant 15: Current solution: [90.66666666666667, 90.66666666666667, 682.6666666666666, 0.0089], Current validation loss: 2.5449419021606445
# Iteration 7, Ant 16: Evaluating...
# num_filters1: 28, num_filters2: 16
# Iteration 7, Ant 16: Current solution: [28.444444444444443, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.7740185260772705
# Iteration 7, Ant 17: Evaluating...
# num_filters1: 28, num_filters2: 78
# Iteration 7, Ant 17: Current solution: [28.444444444444443, 78.22222222222223, 1024.0, 0.005600000000000001], Current validation loss: 3.6271824836730957
# Iteration 7, Ant 18: Evaluating...
# num_filters1: 16, num_filters2: 41
# Iteration 7, Ant 18: Current solution: [16.0, 40.888888888888886, 597.3333333333333, 0.0001], Current validation loss: 2.989732027053833
# Iteration 7, Ant 19: Evaluating...
# num_filters1: 28, num_filters2: 41
# Iteration 7, Ant 19: Current solution: [28.444444444444443, 40.888888888888886, 682.6666666666666, 0.0023], Current validation loss: 3.3882296085357666
# Iteration 7, Ant 20: Evaluating...
# num_filters1: 28, num_filters2: 16
# Iteration 7, Ant 20: Current solution: [28.444444444444443, 16.0, 341.3333333333333, 0.0078000000000000005], Current validation loss: 2.6993370056152344
# Iteration 7: Best solution: [53.333333333333336, 65.77777777777777, 341.3333333333333, 0.01], Best validation loss: 2.321383476257324
# Iteration 8, Ant 1: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 8, Ant 1: Current solution: [16.0, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.7563939094543457
# Iteration 8, Ant 2: Evaluating...
# num_filters1: 103, num_filters2: 16
# Iteration 8, Ant 2: Current solution: [103.11111111111111, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.7203385829925537
# Iteration 8, Ant 3: Evaluating...
# num_filters1: 78, num_filters2: 16
# Iteration 8, Ant 3: Current solution: [78.22222222222223, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.6826961040496826
# Iteration 8, Ant 4: Evaluating...
# num_filters1: 28, num_filters2: 128
# Iteration 8, Ant 4: Current solution: [28.444444444444443, 128.0, 341.3333333333333, 0.0078000000000000005], Current validation loss: 7.061442852020264
# Iteration 8, Ant 5: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 8, Ant 5: Current solution: [16.0, 28.444444444444443, 341.3333333333333, 0.0034], Current validation loss: 2.9157919883728027
# Iteration 8, Ant 6: Evaluating...
# num_filters1: 78, num_filters2: 16
# Iteration 8, Ant 6: Current solution: [78.22222222222223, 16.0, 682.6666666666666, 0.0001], Current validation loss: 3.119626998901367
# Iteration 8, Ant 7: Evaluating...
# num_filters1: 116, num_filters2: 16
# Iteration 8, Ant 7: Current solution: [115.55555555555556, 16.0, 1024.0, 0.0001], Current validation loss: 3.0160529613494873
# Iteration 8, Ant 8: Evaluating...
# num_filters1: 91, num_filters2: 28
# Iteration 8, Ant 8: Current solution: [90.66666666666667, 28.444444444444443, 768.0, 0.0001], Current validation loss: 3.347857713699341
# Iteration 8, Ant 9: Evaluating...
# num_filters1: 28, num_filters2: 16
# Iteration 8, Ant 9: Current solution: [28.444444444444443, 16.0, 341.3333333333333, 0.0067], Current validation loss: 3.6457788944244385
# Iteration 8, Ant 10: Evaluating...
# num_filters1: 28, num_filters2: 103
# Iteration 8, Ant 10: Current solution: [28.444444444444443, 103.11111111111111, 426.66666666666663, 0.0045000000000000005], Current validation loss: 5.490635395050049
# Iteration 8, Ant 11: Evaluating...
# num_filters1: 28, num_filters2: 16
# Iteration 8, Ant 11: Current solution: [28.444444444444443, 16.0, 682.6666666666666, 0.0001], Current validation loss: 3.157335042953491
# Iteration 8, Ant 12: Evaluating...
# num_filters1: 128, num_filters2: 16
# Iteration 8, Ant 12: Current solution: [128.0, 16.0, 853.3333333333333, 0.005600000000000001], Current validation loss: 2.900172710418701
# Iteration 8, Ant 13: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 8, Ant 13: Current solution: [16.0, 16.0, 512.0, 0.0078000000000000005], Current validation loss: 3.207821846008301
# Iteration 8, Ant 14: Evaluating...
# num_filters1: 16, num_filters2: 66
# Iteration 8, Ant 14: Current solution: [16.0, 65.77777777777777, 341.3333333333333, 0.0001], Current validation loss: 3.1790411472320557
# Iteration 8, Ant 15: Evaluating...
# num_filters1: 66, num_filters2: 103
# Iteration 8, Ant 15: Current solution: [65.77777777777777, 103.11111111111111, 341.3333333333333, 0.0001], Current validation loss: 3.664987087249756
# Iteration 8, Ant 16: Evaluating...
# num_filters1: 41, num_filters2: 116
# Iteration 8, Ant 16: Current solution: [40.888888888888886, 115.55555555555556, 768.0, 0.0034], Current validation loss: 4.403090000152588
# Iteration 8, Ant 17: Evaluating...
# num_filters1: 91, num_filters2: 16
# Iteration 8, Ant 17: Current solution: [90.66666666666667, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.6038942337036133
# Iteration 8, Ant 18: Evaluating...
# num_filters1: 41, num_filters2: 66
# Iteration 8, Ant 18: Current solution: [40.888888888888886, 65.77777777777777, 341.3333333333333, 0.0023], Current validation loss: 3.1870715618133545
# Iteration 8, Ant 19: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 8, Ant 19: Current solution: [16.0, 53.333333333333336, 341.3333333333333, 0.0001], Current validation loss: 2.648106098175049
# Iteration 8, Ant 20: Evaluating...
# num_filters1: 66, num_filters2: 53
# Iteration 8, Ant 20: Current solution: [65.77777777777777, 53.333333333333336, 1024.0, 0.0012000000000000001], Current validation loss: 3.2395284175872803
# Iteration 8: Best solution: [53.333333333333336, 65.77777777777777, 341.3333333333333, 0.01], Best validation loss: 2.321383476257324
# Iteration 9, Ant 1: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 9, Ant 1: Current solution: [16.0, 53.333333333333336, 341.3333333333333, 0.0001], Current validation loss: 3.0933685302734375
# Iteration 9, Ant 2: Evaluating...
# num_filters1: 16, num_filters2: 78
# Iteration 9, Ant 2: Current solution: [16.0, 78.22222222222223, 938.6666666666666, 0.0001], Current validation loss: 3.3837194442749023
# Iteration 9, Ant 3: Evaluating...
# num_filters1: 91, num_filters2: 16
# Iteration 9, Ant 3: Current solution: [90.66666666666667, 16.0, 256.0, 0.0012000000000000001], Current validation loss: 3.2086033821105957
# Iteration 9, Ant 4: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 9, Ant 4: Current solution: [16.0, 16.0, 256.0, 0.005600000000000001], Current validation loss: 3.072547435760498
# Iteration 9, Ant 5: Evaluating...
# num_filters1: 103, num_filters2: 16
# Iteration 9, Ant 5: Current solution: [103.11111111111111, 16.0, 341.3333333333333, 0.0078000000000000005], Current validation loss: 3.4386491775512695
# Iteration 9, Ant 6: Evaluating...
# num_filters1: 16, num_filters2: 66
# Iteration 9, Ant 6: Current solution: [16.0, 65.77777777777777, 341.3333333333333, 0.0001], Current validation loss: 2.703571081161499
# Iteration 9, Ant 7: Evaluating...
# num_filters1: 78, num_filters2: 16
# Iteration 9, Ant 7: Current solution: [78.22222222222223, 16.0, 682.6666666666666, 0.005600000000000001], Current validation loss: 3.255793571472168
# Iteration 9, Ant 8: Evaluating...
# num_filters1: 16, num_filters2: 41
# Iteration 9, Ant 8: Current solution: [16.0, 40.888888888888886, 853.3333333333333, 0.0089], Current validation loss: 3.8688817024230957
# Iteration 9, Ant 9: Evaluating...
# num_filters1: 41, num_filters2: 53
# Iteration 9, Ant 9: Current solution: [40.888888888888886, 53.333333333333336, 341.3333333333333, 0.0045000000000000005], Current validation loss: 4.742422103881836
# Iteration 9, Ant 10: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 9, Ant 10: Current solution: [16.0, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.393052816390991
# Iteration 9, Ant 11: Evaluating...
# num_filters1: 91, num_filters2: 41
# Iteration 9, Ant 11: Current solution: [90.66666666666667, 40.888888888888886, 341.3333333333333, 0.01], Current validation loss: 2.977717876434326
# Iteration 9, Ant 12: Evaluating...
# num_filters1: 78, num_filters2: 128
# Iteration 9, Ant 12: Current solution: [78.22222222222223, 128.0, 426.66666666666663, 0.0001], Current validation loss: 3.0430681705474854
# Iteration 9, Ant 13: Evaluating...
# num_filters1: 78, num_filters2: 66
# Iteration 9, Ant 13: Current solution: [78.22222222222223, 65.77777777777777, 341.3333333333333, 0.0023], Current validation loss: 3.6886980533599854
# Iteration 9, Ant 14: Evaluating...
# num_filters1: 66, num_filters2: 16
# Iteration 9, Ant 14: Current solution: [65.77777777777777, 16.0, 1024.0, 0.0078000000000000005], Current validation loss: 1.9104220867156982
# Iteration 9, Ant 15: Evaluating...
# num_filters1: 103, num_filters2: 16
# Iteration 9, Ant 15: Current solution: [103.11111111111111, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.6700830459594727
# Iteration 9, Ant 16: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 9, Ant 16: Current solution: [16.0, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.783611536026001
# Iteration 9, Ant 17: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 9, Ant 17: Current solution: [16.0, 53.333333333333336, 341.3333333333333, 0.0078000000000000005], Current validation loss: 3.9248743057250977
# Iteration 9, Ant 18: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 9, Ant 18: Current solution: [16.0, 16.0, 341.3333333333333, 0.0045000000000000005], Current validation loss: 4.347414016723633
# Iteration 9, Ant 19: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 9, Ant 19: Current solution: [16.0, 16.0, 682.6666666666666, 0.0001], Current validation loss: 2.703507900238037
# Iteration 9, Ant 20: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 9, Ant 20: Current solution: [16.0, 16.0, 341.3333333333333, 0.0023], Current validation loss: 3.765104293823242
# Iteration 9: Best solution: [65.77777777777777, 16.0, 1024.0, 0.0078000000000000005], Best validation loss: 1.9104220867156982
# Iteration 10, Ant 1: Evaluating...
# num_filters1: 41, num_filters2: 41
# Iteration 10, Ant 1: Current solution: [40.888888888888886, 40.888888888888886, 512.0, 0.0089], Current validation loss: 2.6413042545318604
# Iteration 10, Ant 2: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 10, Ant 2: Current solution: [16.0, 16.0, 597.3333333333333, 0.0001], Current validation loss: 2.8679468631744385
# Iteration 10, Ant 3: Evaluating...
# num_filters1: 128, num_filters2: 16
# Iteration 10, Ant 3: Current solution: [128.0, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.9083902835845947
# Iteration 10, Ant 4: Evaluating...
# num_filters1: 128, num_filters2: 53
# Iteration 10, Ant 4: Current solution: [128.0, 53.333333333333336, 341.3333333333333, 0.0001], Current validation loss: 2.801687717437744
# Iteration 10, Ant 5: Evaluating...
# num_filters1: 16, num_filters2: 91
# Iteration 10, Ant 5: Current solution: [16.0, 90.66666666666667, 341.3333333333333, 0.0001], Current validation loss: 2.9695942401885986
# Iteration 10, Ant 6: Evaluating...
# num_filters1: 41, num_filters2: 78
# Iteration 10, Ant 6: Current solution: [40.888888888888886, 78.22222222222223, 341.3333333333333, 0.0001], Current validation loss: 3.4775495529174805
# Iteration 10, Ant 7: Evaluating...
# num_filters1: 53, num_filters2: 66
# Iteration 10, Ant 7: Current solution: [53.333333333333336, 65.77777777777777, 426.66666666666663, 0.0045000000000000005], Current validation loss: 3.905071973800659
# Iteration 10, Ant 8: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 10, Ant 8: Current solution: [16.0, 16.0, 341.3333333333333, 0.0001], Current validation loss: 2.4139082431793213
# Iteration 10, Ant 9: Evaluating...
# num_filters1: 66, num_filters2: 28
# Iteration 10, Ant 9: Current solution: [65.77777777777777, 28.444444444444443, 341.3333333333333, 0.0001], Current validation loss: 3.278798818588257
# Iteration 10, Ant 10: Evaluating...
# num_filters1: 128, num_filters2: 16
# Iteration 10, Ant 10: Current solution: [128.0, 16.0, 341.3333333333333, 0.0089], Current validation loss: 2.382847309112549
# Iteration 10, Ant 11: Evaluating...
# num_filters1: 78, num_filters2: 16
# Iteration 10, Ant 11: Current solution: [78.22222222222223, 16.0, 768.0, 0.0089], Current validation loss: 2.681791305541992
# Iteration 10, Ant 12: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 10, Ant 12: Current solution: [16.0, 16.0, 1024.0, 0.0001], Current validation loss: 3.0229456424713135
# Iteration 10, Ant 13: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 10, Ant 13: Current solution: [16.0, 16.0, 426.66666666666663, 0.0089], Current validation loss: 2.4030537605285645
# Iteration 10, Ant 14: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 10, Ant 14: Current solution: [16.0, 16.0, 341.3333333333333, 0.0089], Current validation loss: 3.6937437057495117
# Iteration 10, Ant 15: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 10, Ant 15: Current solution: [16.0, 16.0, 682.6666666666666, 0.0001], Current validation loss: 2.826312780380249
# Iteration 10, Ant 16: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 10, Ant 16: Current solution: [16.0, 28.444444444444443, 341.3333333333333, 0.0001], Current validation loss: 3.6506245136260986
# Iteration 10, Ant 17: Evaluating...
# num_filters1: 103, num_filters2: 128
# Iteration 10, Ant 17: Current solution: [103.11111111111111, 128.0, 341.3333333333333, 0.0001], Current validation loss: 3.3848280906677246
# Iteration 10, Ant 18: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 10, Ant 18: Current solution: [16.0, 16.0, 512.0, 0.0012000000000000001], Current validation loss: 3.078549861907959
# Iteration 10, Ant 19: Evaluating...
# num_filters1: 53, num_filters2: 128
# Iteration 10, Ant 19: Current solution: [53.333333333333336, 128.0, 341.3333333333333, 0.0001], Current validation loss: 3.113332748413086
# Iteration 10, Ant 20: Evaluating...
# num_filters1: 78, num_filters2: 16
# Iteration 10, Ant 20: Current solution: [78.22222222222223, 16.0, 768.0, 0.0023], Current validation loss: 3.8220889568328857
# Iteration 10: Best solution: [65.77777777777777, 16.0, 1024.0, 0.0078000000000000005], Best validation loss: 1.9104220867156982
# Iteration 11, Ant 1: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 11, Ant 1: Current solution: [16.0, 16.0, 341.3333333333333, 0.0001], Current validation loss: 3.2950639724731445
# Iteration 11, Ant 2: Evaluating...
# num_filters1: 16, num_filters2: 66
# Iteration 11, Ant 2: Current solution: [16.0, 65.77777777777777, 341.3333333333333, 0.0001], Current validation loss: 3.0883405208587646
# Iteration 11, Ant 3: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 11, Ant 3: Current solution: [16.0, 16.0, 341.3333333333333, 0.01], Current validation loss: 4.374279022216797
# Iteration 11, Ant 4: Evaluating...
# num_filters1: 41, num_filters2: 66
# Iteration 11, Ant 4: Current solution: [40.888888888888886, 65.77777777777777, 768.0, 0.0078000000000000005], Current validation loss: 3.275010347366333
# Iteration 11, Ant 5: Evaluating...
# num_filters1: 16, num_filters2: 116
# Iteration 11, Ant 5: Current solution: [16.0, 115.55555555555556, 341.3333333333333, 0.01], Current validation loss: 2.3581526279449463
# Iteration 11, Ant 6: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 11, Ant 6: Current solution: [16.0, 53.333333333333336, 768.0, 0.0078000000000000005], Current validation loss: 3.089773178100586
# Iteration 11, Ant 7: Evaluating...
# num_filters1: 16, num_filters2: 103
# Iteration 11, Ant 7: Current solution: [16.0, 103.11111111111111, 512.0, 0.0001], Current validation loss: 3.4049456119537354
# Iteration 11, Ant 8: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 11, Ant 8: Current solution: [16.0, 16.0, 256.0, 0.0001], Current validation loss: 3.231771469116211
# Iteration 11, Ant 9: Evaluating...
# num_filters1: 91, num_filters2: 16
# Iteration 11, Ant 9: Current solution: [90.66666666666667, 16.0, 597.3333333333333, 0.0001], Current validation loss: 3.353015184402466
# Iteration 11, Ant 10: Evaluating...
# num_filters1: 16, num_filters2: 116
# Iteration 11, Ant 10: Current solution: [16.0, 115.55555555555556, 341.3333333333333, 0.0001], Current validation loss: 4.100334167480469
# Iteration 11, Ant 11: Evaluating...
# num_filters1: 16, num_filters2: 103
# Iteration 11, Ant 11: Current solution: [16.0, 103.11111111111111, 341.3333333333333, 0.0001], Current validation loss: 2.831017255783081
# Iteration 11, Ant 12: Evaluating...
# num_filters1: 16, num_filters2: 128
# Iteration 11, Ant 12: Current solution: [16.0, 128.0, 341.3333333333333, 0.0001], Current validation loss: 3.1027944087982178
# Iteration 11, Ant 13: Evaluating...
# num_filters1: 16, num_filters2: 41
# Iteration 11, Ant 13: Current solution: [16.0, 40.888888888888886, 512.0, 0.0067], Current validation loss: 4.554453372955322
# Iteration 11, Ant 14: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 11, Ant 14: Current solution: [16.0, 16.0, 682.6666666666666, 0.0001], Current validation loss: 2.8620102405548096
# Iteration 11, Ant 15: Evaluating...
# num_filters1: 116, num_filters2: 16
# Iteration 11, Ant 15: Current solution: [115.55555555555556, 16.0, 341.3333333333333, 0.0001], Current validation loss: 3.080144166946411
# Iteration 11, Ant 16: Evaluating...
# num_filters1: 16, num_filters2: 41
# Iteration 11, Ant 16: Current solution: [16.0, 40.888888888888886, 853.3333333333333, 0.0001], Current validation loss: 2.8701889514923096
# Iteration 11, Ant 17: Evaluating...
# num_filters1: 116, num_filters2: 16
# Iteration 11, Ant 17: Current solution: [115.55555555555556, 16.0, 768.0, 0.0001], Current validation loss: 3.6424973011016846
# Iteration 11, Ant 18: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 11, Ant 18: Current solution: [16.0, 16.0, 1024.0, 0.0089], Current validation loss: 3.6793975830078125
# Iteration 11, Ant 19: Evaluating...
# num_filters1: 116, num_filters2: 53
# Iteration 11, Ant 19: Current solution: [115.55555555555556, 53.333333333333336, 768.0, 0.0089], Current validation loss: 3.819349527359009
# Iteration 11, Ant 20: Evaluating...
# num_filters1: 128, num_filters2: 103
# Iteration 11, Ant 20: Current solution: [128.0, 103.11111111111111, 768.0, 0.0001], Current validation loss: 4.005457401275635
# Iteration 11: Best solution: [65.77777777777777, 16.0, 1024.0, 0.0078000000000000005], Best validation loss: 1.9104220867156982
# Iteration 12, Ant 1: Evaluating...
# num_filters1: 16, num_filters2: 78
# Iteration 12, Ant 1: Current solution: [16.0, 78.22222222222223, 768.0, 0.0001], Current validation loss: 3.2227377891540527
# Iteration 12, Ant 2: Evaluating...
# num_filters1: 41, num_filters2: 16
# Iteration 12, Ant 2: Current solution: [40.888888888888886, 16.0, 768.0, 0.0001], Current validation loss: 3.4929497241973877
# Iteration 12, Ant 3: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 12, Ant 3: Current solution: [16.0, 28.444444444444443, 768.0, 0.0001], Current validation loss: 3.1142280101776123
# Iteration 12, Ant 4: Evaluating...
# num_filters1: 116, num_filters2: 41
# Iteration 12, Ant 4: Current solution: [115.55555555555556, 40.888888888888886, 341.3333333333333, 0.0001], Current validation loss: 2.9378836154937744
# Iteration 12, Ant 5: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 12, Ant 5: Current solution: [16.0, 16.0, 768.0, 0.005600000000000001], Current validation loss: 2.8739266395568848
# Iteration 12, Ant 6: Evaluating...
# num_filters1: 91, num_filters2: 16
# Iteration 12, Ant 6: Current solution: [90.66666666666667, 16.0, 768.0, 0.0001], Current validation loss: 3.1009905338287354
# Iteration 12, Ant 7: Evaluating...
# num_filters1: 16, num_filters2: 16
# Iteration 12, Ant 7: Current solution: [16.0, 16.0, 512.0, 0.0001], Current validation loss: 2.6925113201141357
# Iteration 12, Ant 8: Evaluating...
# num_filters1: 16, num_filters2: 128
# Iteration 12, Ant 8: Current solution: [16.0, 128.0, 1024.0, 0.0001], Current validation loss: 3.580791711807251
# Iteration 12, Ant 9: Evaluating...
# ...
# Iteration 18: Best solution: [65.77777777777777, 16.0, 1024.0, 0.0078000000000000005], Best validation loss: 1.9104220867156982
# Iteration 19, Ant 1: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 19, Ant 1: Current solution: [16.0, 28.444444444444443, 768.0, 0.01], Current validation loss: 3.8450074195861816
# Iteration 19, Ant 2: Evaluating...
# num_filters1: 16, num_filters2: 91
# Iteration 19, Ant 2: Current solution: [16.0, 90.66666666666667, 853.3333333333333, 0.0001], Current validation loss: 3.870551109313965
# Iteration 19, Ant 3: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 19, Ant 3: Current solution: [16.0, 28.444444444444443, 597.3333333333333, 0.0001], Current validation loss: 3.037119150161743
# Iteration 19, Ant 4: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 19, Ant 4: Current solution: [16.0, 28.444444444444443, 512.0, 0.0089], Current validation loss: 2.61727237701416
# Iteration 19, Ant 5: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 19, Ant 5: Current solution: [16.0, 28.444444444444443, 341.3333333333333, 0.01], Current validation loss: 3.2859816551208496
# Iteration 19, Ant 6: Evaluating...
# num_filters1: 66, num_filters2: 28
# Iteration 19, Ant 6: Current solution: [65.77777777777777, 28.444444444444443, 341.3333333333333, 0.0045000000000000005], Current validation loss: 3.9095497131347656
# Iteration 19, Ant 7: Evaluating...
# num_filters1: 128, num_filters2: 78
# Iteration 19, Ant 7: Current solution: [128.0, 78.22222222222223, 341.3333333333333, 0.0001], Current validation loss: 3.2424089908599854
# Iteration 19, Ant 8: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 19, Ant 8: Current solution: [16.0, 28.444444444444443, 341.3333333333333, 0.0001], Current validation loss: 3.128429651260376
# Iteration 19, Ant 9: Evaluating...
# num_filters1: 16, num_filters2: 78
# Iteration 19, Ant 9: Current solution: [16.0, 78.22222222222223, 341.3333333333333, 0.0001], Current validation loss: 3.2637763023376465
# Iteration 19, Ant 10: Evaluating...
# num_filters1: 41, num_filters2: 28
# Iteration 19, Ant 10: Current solution: [40.888888888888886, 28.444444444444443, 341.3333333333333, 0.0001], Current validation loss: 3.067861318588257
# Iteration 19, Ant 11: Evaluating...
# num_filters1: 78, num_filters2: 66
# Iteration 19, Ant 11: Current solution: [78.22222222222223, 65.77777777777777, 682.6666666666666, 0.01], Current validation loss: 4.679738521575928
# Iteration 19, Ant 12: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 19, Ant 12: Current solution: [16.0, 28.444444444444443, 341.3333333333333, 0.0034], Current validation loss: 3.2641196250915527
# Iteration 19, Ant 13: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 19, Ant 13: Current solution: [16.0, 28.444444444444443, 512.0, 0.01], Current validation loss: 3.3242082595825195
# Iteration 19, Ant 14: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 19, Ant 14: Current solution: [16.0, 28.444444444444443, 426.66666666666663, 0.0001], Current validation loss: 3.0367817878723145
# Iteration 19, Ant 15: Evaluating...
# num_filters1: 41, num_filters2: 28
# Iteration 19, Ant 15: Current solution: [40.888888888888886, 28.444444444444443, 768.0, 0.0001], Current validation loss: 3.0712637901306152
# Iteration 19, Ant 16: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 19, Ant 16: Current solution: [16.0, 28.444444444444443, 341.3333333333333, 0.0001], Current validation loss: 2.750739812850952
# Iteration 19, Ant 17: Evaluating...
# num_filters1: 53, num_filters2: 78
# Iteration 19, Ant 17: Current solution: [53.333333333333336, 78.22222222222223, 341.3333333333333, 0.01], Current validation loss: 2.363105058670044
# Iteration 19, Ant 18: Evaluating...
# num_filters1: 16, num_filters2: 116
# Iteration 19, Ant 18: Current solution: [16.0, 115.55555555555556, 341.3333333333333, 0.0023], Current validation loss: 5.488701820373535
# Iteration 19, Ant 19: Evaluating...
# num_filters1: 91, num_filters2: 53
# Iteration 19, Ant 19: Current solution: [90.66666666666667, 53.333333333333336, 341.3333333333333, 0.0001], Current validation loss: 2.824768543243408
# Iteration 19, Ant 20: Evaluating...
# num_filters1: 16, num_filters2: 66
# Iteration 19, Ant 20: Current solution: [16.0, 65.77777777777777, 341.3333333333333, 0.0001], Current validation loss: 3.8307883739471436
# Iteration 19: Best solution: [65.77777777777777, 16.0, 1024.0, 0.0078000000000000005], Best validation loss: 1.9104220867156982
# Iteration 20, Ant 1: Evaluating...
# num_filters1: 28, num_filters2: 91
# Iteration 20, Ant 1: Current solution: [28.444444444444443, 90.66666666666667, 597.3333333333333, 0.0023], Current validation loss: 5.806334972381592
# Iteration 20, Ant 2: Evaluating...
# num_filters1: 28, num_filters2: 66
# Iteration 20, Ant 2: Current solution: [28.444444444444443, 65.77777777777777, 1024.0, 0.0001], Current validation loss: 3.159536600112915
# Iteration 20, Ant 3: Evaluating...
# num_filters1: 16, num_filters2: 28
# Iteration 20, Ant 3: Current solution: [16.0, 28.444444444444443, 1024.0, 0.0045000000000000005], Current validation loss: 5.563362121582031
# Iteration 20, Ant 4: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 20, Ant 4: Current solution: [16.0, 53.333333333333336, 341.3333333333333, 0.0001], Current validation loss: 3.0216193199157715
# Iteration 20, Ant 5: Evaluating...
# num_filters1: 28, num_filters2: 66
# Iteration 20, Ant 5: Current solution: [28.444444444444443, 65.77777777777777, 341.3333333333333, 0.0012000000000000001], Current validation loss: 3.3754913806915283
# Iteration 20, Ant 6: Evaluating...
# num_filters1: 16, num_filters2: 66
# Iteration 20, Ant 6: Current solution: [16.0, 65.77777777777777, 597.3333333333333, 0.0001], Current validation loss: 3.12670636177063
# Iteration 20, Ant 7: Evaluating...
# num_filters1: 78, num_filters2: 28
# Iteration 20, Ant 7: Current solution: [78.22222222222223, 28.444444444444443, 256.0, 0.0023], Current validation loss: 4.125173568725586
# Iteration 20, Ant 8: Evaluating...
# num_filters1: 128, num_filters2: 28
# Iteration 20, Ant 8: Current solution: [128.0, 28.444444444444443, 682.6666666666666, 0.0067], Current validation loss: 4.473875045776367
# Iteration 20, Ant 9: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 20, Ant 9: Current solution: [16.0, 53.333333333333336, 341.3333333333333, 0.0001], Current validation loss: 3.749891757965088
# Iteration 20, Ant 10: Evaluating...
# num_filters1: 91, num_filters2: 66
# Iteration 20, Ant 10: Current solution: [90.66666666666667, 65.77777777777777, 1024.0, 0.0001], Current validation loss: 3.3453750610351562
# Iteration 20, Ant 11: Evaluating...
# num_filters1: 41, num_filters2: 103
# Iteration 20, Ant 11: Current solution: [40.888888888888886, 103.11111111111111, 768.0, 0.0012000000000000001], Current validation loss: 2.85921311378479
# Iteration 20, Ant 12: Evaluating...
# num_filters1: 16, num_filters2: 66
# Iteration 20, Ant 12: Current solution: [16.0, 65.77777777777777, 341.3333333333333, 0.0001], Current validation loss: 3.4798800945281982
# Iteration 20, Ant 13: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 20, Ant 13: Current solution: [16.0, 53.333333333333336, 768.0, 0.0089], Current validation loss: 2.733057975769043
# Iteration 20, Ant 14: Evaluating...
# num_filters1: 16, num_filters2: 103
# Iteration 20, Ant 14: Current solution: [16.0, 103.11111111111111, 341.3333333333333, 0.0078000000000000005], Current validation loss: 4.1620659828186035
# Iteration 20, Ant 15: Evaluating...
# num_filters1: 91, num_filters2: 53
# Iteration 20, Ant 15: Current solution: [90.66666666666667, 53.333333333333336, 853.3333333333333, 0.0001], Current validation loss: 3.2618308067321777
# Iteration 20, Ant 16: Evaluating...
# num_filters1: 103, num_filters2: 66
# Iteration 20, Ant 16: Current solution: [103.11111111111111, 65.77777777777777, 768.0, 0.0089], Current validation loss: 6.027128219604492
# Iteration 20, Ant 17: Evaluating...
# num_filters1: 16, num_filters2: 53
# Iteration 20, Ant 17: Current solution: [16.0, 53.333333333333336, 341.3333333333333, 0.0001], Current validation loss: 2.4634668827056885
# Iteration 20, Ant 18: Evaluating...
# num_filters1: 53, num_filters2: 66
# Iteration 20, Ant 18: Current solution: [53.333333333333336, 65.77777777777777, 1024.0, 0.0001], Current validation loss: 3.4288508892059326
# Iteration 20, Ant 19: Evaluating...
# num_filters1: 53, num_filters2: 78
# Iteration 20, Ant 19: Current solution: [53.333333333333336, 78.22222222222223, 341.3333333333333, 0.0001], Current validation loss: 2.7630538940429688
# Iteration 20, Ant 20: Evaluating...
# num_filters1: 41, num_filters2: 91
# Iteration 20, Ant 20: Current solution: [40.888888888888886, 90.66666666666667, 1024.0, 0.0012000000000000001], Current validation loss: 3.6563024520874023
# Iteration 20: Best solution: [65.77777777777777, 16.0, 1024.0, 0.0078000000000000005], Best validation loss: 1.9104220867156982
# Best hyperparameters found by ACO: num_filters1=65, num_filters2=16, dense_units=1024, learning_rate=0.0078000000000000005
# Training the model with the best hyperparameters...
# Epoch 1/50
# 704/704 [==============================] - 195s 276ms/step - loss: 1.9683 - accuracy: 0.3837 - val_loss: 1.4223 - val_accuracy: 0.4990
# Epoch 2/50
# 704/704 [==============================] - 189s 269ms/step - loss: 1.2358 - accuracy: 0.5569 - val_loss: 1.5321 - val_accuracy: 0.4716
# Epoch 3/50
# 704/704 [==============================] - 190s 270ms/step - loss: 1.0766 - accuracy: 0.6183 - val_loss: 1.0227 - val_accuracy: 0.6454
# Epoch 4/50
# 704/704 [==============================] - 186s 264ms/step - loss: 1.0095 - accuracy: 0.6454 - val_loss: 0.9716 - val_accuracy: 0.6708
# Epoch 5/50
# 704/704 [==============================] - 204s 289ms/step - loss: 0.9440 - accuracy: 0.6701 - val_loss: 1.0165 - val_accuracy: 0.6634
# Epoch 6/50
# 704/704 [==============================] - 201s 285ms/step - loss: 0.9034 - accuracy: 0.6847 - val_loss: 0.9044 - val_accuracy: 0.6942
# Epoch 7/50
# 704/704 [==============================] - 190s 270ms/step - loss: 0.8746 - accuracy: 0.6932 - val_loss: 1.0471 - val_accuracy: 0.6434
# Epoch 8/50
# 704/704 [==============================] - 192s 273ms/step - loss: 0.8544 - accuracy: 0.7016 - val_loss: 0.7919 - val_accuracy: 0.7310
# Epoch 9/50
# 704/704 [==============================] - 195s 277ms/step - loss: 0.8275 - accuracy: 0.7124 - val_loss: 0.7604 - val_accuracy: 0.7392
# Epoch 10/50
# 704/704 [==============================] - 188s 267ms/step - loss: 0.7905 - accuracy: 0.7271 - val_loss: 0.7239 - val_accuracy: 0.7454
# Epoch 11/50
# 704/704 [==============================] - 181s 257ms/step - loss: 0.7858 - accuracy: 0.7283 - val_loss: 0.7462 - val_accuracy: 0.7472
# Epoch 12/50
# 704/704 [==============================] - 183s 260ms/step - loss: 0.7447 - accuracy: 0.7411 - val_loss: 0.8468 - val_accuracy: 0.7086
# Epoch 13/50
# 704/704 [==============================] - 186s 265ms/step - loss: 0.7388 - accuracy: 0.7457 - val_loss: 0.9457 - val_accuracy: 0.6788
# Epoch 14/50
# 704/704 [==============================] - 187s 266ms/step - loss: 0.7575 - accuracy: 0.7393 - val_loss: 0.7144 - val_accuracy: 0.7562
# Epoch 15/50
# 704/704 [==============================] - 185s 263ms/step - loss: 0.7102 - accuracy: 0.7550 - val_loss: 0.6689 - val_accuracy: 0.7786
# Epoch 16/50
# 704/704 [==============================] - 197s 279ms/step - loss: 0.6842 - accuracy: 0.7639 - val_loss: 0.7441 - val_accuracy: 0.7516
# Epoch 17/50
# 704/704 [==============================] - 187s 266ms/step - loss: 0.6755 - accuracy: 0.7662 - val_loss: 0.6965 - val_accuracy: 0.7628
# Epoch 18/50
# 704/704 [==============================] - 198s 282ms/step - loss: 0.7023 - accuracy: 0.7573 - val_loss: 0.6767 - val_accuracy: 0.7688
# Epoch 19/50
# 704/704 [==============================] - 204s 290ms/step - loss: 0.6555 - accuracy: 0.7729 - val_loss: 0.8078 - val_accuracy: 0.7258
# Epoch 20/50
# 704/704 [==============================] - 188s 267ms/step - loss: 0.6523 - accuracy: 0.7781 - val_loss: 0.6651 - val_accuracy: 0.7666
# Epoch 21/50
# 704/704 [==============================] - 193s 273ms/step - loss: 0.6331 - accuracy: 0.7817 - val_loss: 0.7732 - val_accuracy: 0.7548
# Epoch 22/50
# 704/704 [==============================] - 197s 280ms/step - loss: 0.6223 - accuracy: 0.7866 - val_loss: 0.6467 - val_accuracy: 0.7864
# Epoch 23/50
# 704/704 [==============================] - 194s 275ms/step - loss: 0.6063 - accuracy: 0.7928 - val_loss: 0.6553 - val_accuracy: 0.7846
# Epoch 24/50
# 704/704 [==============================] - 197s 281ms/step - loss: 0.6079 - accuracy: 0.7925 - val_loss: 0.6652 - val_accuracy: 0.7672
# Epoch 25/50
# 704/704 [==============================] - 186s 264ms/step - loss: 0.5983 - accuracy: 0.7954 - val_loss: 0.7039 - val_accuracy: 0.7620
# Epoch 26/50
# 704/704 [==============================] - 192s 272ms/step - loss: 0.5963 - accuracy: 0.7949 - val_loss: 0.6863 - val_accuracy: 0.7714
# Epoch 27/50
# 704/704 [==============================] - 196s 279ms/step - loss: 0.5703 - accuracy: 0.8040 - val_loss: 0.6200 - val_accuracy: 0.7944
# Epoch 28/50
# 704/704 [==============================] - 196s 278ms/step - loss: 0.5723 - accuracy: 0.8035 - val_loss: 0.7095 - val_accuracy: 0.7730
# Epoch 29/50
# 704/704 [==============================] - 195s 277ms/step - loss: 0.5725 - accuracy: 0.8036 - val_loss: 0.6846 - val_accuracy: 0.7802
# Epoch 30/50
# 704/704 [==============================] - 193s 274ms/step - loss: 0.5825 - accuracy: 0.8007 - val_loss: 0.6432 - val_accuracy: 0.7842
# Epoch 31/50
# 704/704 [==============================] - 187s 266ms/step - loss: 0.5955 - accuracy: 0.7971 - val_loss: 0.6531 - val_accuracy: 0.7850
# Epoch 32/50
# 704/704 [==============================] - 192s 273ms/step - loss: 0.5494 - accuracy: 0.8128 - val_loss: 0.6240 - val_accuracy: 0.7964
# Epoch 33/50
# 704/704 [==============================] - 187s 266ms/step - loss: 0.5326 - accuracy: 0.8190 - val_loss: 0.7361 - val_accuracy: 0.7722
# Epoch 34/50
# 704/704 [==============================] - 192s 272ms/step - loss: 0.5325 - accuracy: 0.8198 - val_loss: 0.6578 - val_accuracy: 0.7820
# Epoch 35/50
# 704/704 [==============================] - 183s 260ms/step - loss: 0.5310 - accuracy: 0.8203 - val_loss: 0.6506 - val_accuracy: 0.7914
# Epoch 36/50
# 704/704 [==============================] - 190s 270ms/step - loss: 0.5263 - accuracy: 0.8214 - val_loss: 0.7127 - val_accuracy: 0.7800
# Epoch 37/50
# 704/704 [==============================] - 191s 272ms/step - loss: 0.5435 - accuracy: 0.8158 - val_loss: 0.6736 - val_accuracy: 0.7800
# Total training time: 7091.34 seconds
# Evaluating the model on the test dataset...
# 313/313 [==============================] - 12s 38ms/step
# Test accuracy: 0.7937999963760376
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80      1000
#            1       0.86      0.94      0.90      1000
#            2       0.63      0.77      0.70      1000
#            3       0.66      0.59      0.62      1000
#            4       0.78      0.77      0.77      1000
#            5       0.76      0.66      0.71      1000
#            6       0.82      0.87      0.84      1000
#            7       0.91      0.77      0.83      1000
#            8       0.88      0.88      0.88      1000
#            9       0.93      0.84      0.88      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.80      0.79      0.79     10000
# weighted avg       0.80      0.79      0.79     10000
#
# Confusion Matrix:
# [[849  16  42   7   3   2   9   4  56  12]
#  [ 19 943   3   0   1   1   1   0   7  25]
#  [ 55   4 772  25  59  22  45   5  11   2]
#  [ 34  10  97 594  49 113  75  18   6   4]
#  [ 20   4  72  48 768  21  28  30   8   1]
#  [ 17   6  91 146  30 658  23  19   4   6]
#  [  4   2  53  30  37   3 866   3   2   0]
#  [ 27   4  68  40  36  40   4 768   7   6]
#  [ 49  32  15   7   2   1   4   0 881   9]
#  [ 44  72   7   8   2   2   2   1  23 839]]
# ROC-AUC Score: 0.9762632055555557
# Plotting the training and validation accuracies...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data
confusion_matrix = np.array([
    [849, 16, 42, 7, 3, 2, 9, 4, 56, 12],
    [19, 943, 3, 0, 1, 1, 1, 0, 7, 25],
    [55, 4, 772, 25, 59, 22, 45, 5, 11, 2],
    [34, 10, 97, 594, 49, 113, 75, 18, 6, 4],
    [20, 4, 72, 48, 768, 21, 28, 30, 8, 1],
    [17, 6, 91, 146, 30, 658, 23, 19, 4, 6],
    [4, 2, 53, 30, 37, 3, 866, 3, 2, 0],
    [27, 4, 68, 40, 36, 40, 4, 768, 7, 6],
    [49, 32, 15, 7, 2, 1, 4, 0, 881, 9],
    [44, 72, 7, 8, 2, 2, 2, 1, 23, 839]
])

# Class names
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
